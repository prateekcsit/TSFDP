# %% [markdown]
# ## We will explore a data set dedicated to the cost of treatment of different patients

# %%
### Import libraries

# %%
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
data = pd.read_csv('../datasets/insurance.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# ### Perform EDA

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# #### Check for "NaN"in the data

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# #### Encode categorical features

# %%
from sklearn.preprocessing import LabelEncoder
#sex
le = LabelEncoder()
data.sex = le.fit_transform(data.sex) 
# smoker or not
data.smoker = le.fit_transform(data.smoker)
#region
#le.fit(data.region.drop_duplicates()) 
data.region = le.fit_transform(data.region)

# %%
data.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520

# %% [markdown]
# ## Check the Correlation

# %%
corr = data.corr()
corr.style.background_gradient(cmap='rainbow')
# Out:
# <style  type="text/css" >
# #T_1043e_row0_col0,#T_1043e_row1_col1,#T_1043e_row2_col2,#T_1043e_row3_col3,#T_1043e_row4_col4,#T_1043e_row5_col5,#T_1043e_row6_col6{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_1043e_row0_col1,#T_1043e_row0_col4,#T_1043e_row4_col0,#T_1043e_row4_col2,#T_1043e_row4_col3,#T_1043e_row5_col6,#T_1043e_row6_col5{
#             background-color:  #8000ff;
#             color:  #f1f1f1;
#         }#T_1043e_row0_col2{
#             background-color:  #4a53fb;
#             color:  #f1f1f1;
#         }#T_1043e_row0_col3,#T_1043e_row3_col4{
#             background-color:  #7019ff;
#             color:  #f1f1f1;
#         }#T_1043e_row0_col5,#T_1043e_row1_col3,#T_1043e_row1_col5,#T_1043e_row3_col2,#T_1043e_row5_col3{
#             background-color:  #7c06ff;
#             color:  #f1f1f1;
#         }#T_1043e_row0_col6{
#             background-color:  #1acfe3;
#             color:  #000000;
#         }#T_1043e_row1_col0,#T_1043e_row2_col3,#T_1043e_row4_col5{
#             background-color:  #7e03ff;
#             color:  #f1f1f1;
#         }#T_1043e_row1_col2{
#             background-color:  #6c1fff;
#             color:  #f1f1f1;
#         }#T_1043e_row1_col4{
#             background-color:  #4e4dfc;
#             color:  #f1f1f1;
#         }#T_1043e_row1_col6,#T_1043e_row2_col1,#T_1043e_row3_col0{
#             background-color:  #6032fe;
#             color:  #f1f1f1;
#         }#T_1043e_row2_col0{
#             background-color:  #3e65fa;
#             color:  #f1f1f1;
#         }#T_1043e_row2_col4{
#             background-color:  #7216ff;
#             color:  #f1f1f1;
#         }#T_1043e_row2_col5{
#             background-color:  #2e7bf7;
#             color:  #000000;
#         }#T_1043e_row2_col6{
#             background-color:  #1898f2;
#             color:  #000000;
#         }#T_1043e_row3_col1{
#             background-color:  #6e1cff;
#             color:  #f1f1f1;
#         }#T_1043e_row3_col5,#T_1043e_row5_col4{
#             background-color:  #7610ff;
#             color:  #f1f1f1;
#         }#T_1043e_row3_col6{
#             background-color:  #5c38fd;
#             color:  #f1f1f1;
#         }#T_1043e_row4_col1{
#             background-color:  #504afc;
#             color:  #f1f1f1;
#         }#T_1043e_row4_col6{
#             background-color:  #ff9d53;
#             color:  #000000;
#         }#T_1043e_row5_col0,#T_1043e_row5_col1{
#             background-color:  #7413ff;
#             color:  #f1f1f1;
#         }#T_1043e_row5_col2{
#             background-color:  #3176f8;
#             color:  #000000;
#         }#T_1043e_row6_col0{
#             background-color:  #20d5e1;
#             color:  #000000;
#         }#T_1043e_row6_col1{
#             background-color:  #5a3bfd;
#             color:  #f1f1f1;
#         }#T_1043e_row6_col2{
#             background-color:  #1c93f3;
#             color:  #000000;
#         }#T_1043e_row6_col3{
#             background-color:  #622ffe;
#             color:  #f1f1f1;
#         }#T_1043e_row6_col4{
#             background-color:  #ff9b52;
#             color:  #000000;
#         }</style><table id="T_1043e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >age</th>        <th class="col_heading level0 col1" >sex</th>        <th class="col_heading level0 col2" >bmi</th>        <th class="col_heading level0 col3" >children</th>        <th class="col_heading level0 col4" >smoker</th>        <th class="col_heading level0 col5" >region</th>        <th class="col_heading level0 col6" >charges</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1043e_level0_row0" class="row_heading level0 row0" >age</th>
#                         <td id="T_1043e_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_1043e_row0_col1" class="data row0 col1" >-0.020856</td>
#                         <td id="T_1043e_row0_col2" class="data row0 col2" >0.109272</td>
#                         <td id="T_1043e_row0_col3" class="data row0 col3" >0.042469</td>
#                         <td id="T_1043e_row0_col4" class="data row0 col4" >-0.025019</td>
#                         <td id="T_1043e_row0_col5" class="data row0 col5" >0.002127</td>
#                         <td id="T_1043e_row0_col6" class="data row0 col6" >0.299008</td>
#             </tr>
#             <tr>
#                         <th id="T_1043e_level0_row1" class="row_heading level0 row1" >sex</th>
#                         <td id="T_1043e_row1_col0" class="data row1 col0" >-0.020856</td>
#                         <td id="T_1043e_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_1043e_row1_col2" class="data row1 col2" >0.046371</td>
#                         <td id="T_1043e_row1_col3" class="data row1 col3" >0.017163</td>
#                         <td id="T_1043e_row1_col4" class="data row1 col4" >0.076185</td>
#                         <td id="T_1043e_row1_col5" class="data row1 col5" >0.004588</td>
#                         <td id="T_1043e_row1_col6" class="data row1 col6" >0.057292</td>
#             </tr>
#             <tr>
#                         <th id="T_1043e_level0_row2" class="row_heading level0 row2" >bmi</th>
#                         <td id="T_1043e_row2_col0" class="data row2 col0" >0.109272</td>
#                         <td id="T_1043e_row2_col1" class="data row2 col1" >0.046371</td>
#                         <td id="T_1043e_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_1043e_row2_col3" class="data row2 col3" >0.012759</td>
#                         <td id="T_1043e_row2_col4" class="data row2 col4" >0.003750</td>
#                         <td id="T_1043e_row2_col5" class="data row2 col5" >0.157566</td>
#                         <td id="T_1043e_row2_col6" class="data row2 col6" >0.198341</td>
#             </tr>
#             <tr>
#                         <th id="T_1043e_level0_row3" class="row_heading level0 row3" >children</th>
#                         <td id="T_1043e_row3_col0" class="data row3 col0" >0.042469</td>
#                         <td id="T_1043e_row3_col1" class="data row3 col1" >0.017163</td>
#                         <td id="T_1043e_row3_col2" class="data row3 col2" >0.012759</td>
#                         <td id="T_1043e_row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_1043e_row3_col4" class="data row3 col4" >0.007673</td>
#                         <td id="T_1043e_row3_col5" class="data row3 col5" >0.016569</td>
#                         <td id="T_1043e_row3_col6" class="data row3 col6" >0.067998</td>
#             </tr>
#             <tr>
#                         <th id="T_1043e_level0_row4" class="row_heading level0 row4" >smoker</th>
#                         <td id="T_1043e_row4_col0" class="data row4 col0" >-0.025019</td>
#                         <td id="T_1043e_row4_col1" class="data row4 col1" >0.076185</td>
#                         <td id="T_1043e_row4_col2" class="data row4 col2" >0.003750</td>
#                         <td id="T_1043e_row4_col3" class="data row4 col3" >0.007673</td>
#                         <td id="T_1043e_row4_col4" class="data row4 col4" >1.000000</td>
#                         <td id="T_1043e_row4_col5" class="data row4 col5" >-0.002181</td>
#                         <td id="T_1043e_row4_col6" class="data row4 col6" >0.787251</td>
#             </tr>
#             <tr>
#                         <th id="T_1043e_level0_row5" class="row_heading level0 row5" >region</th>
#                         <td id="T_1043e_row5_col0" class="data row5 col0" >0.002127</td>
#                         <td id="T_1043e_row5_col1" class="data row5 col1" >0.004588</td>
#                         <td id="T_1043e_row5_col2" class="data row5 col2" >0.157566</td>
#                         <td id="T_1043e_row5_col3" class="data row5 col3" >0.016569</td>
#                         <td id="T_1043e_row5_col4" class="data row5 col4" >-0.002181</td>
#                         <td id="T_1043e_row5_col5" class="data row5 col5" >1.000000</td>
#                         <td id="T_1043e_row5_col6" class="data

# %%
data.corr()['charges'].sort_values()
# Out:
# region     -0.006208
# sex         0.057292
# children    0.067998
# bmi         0.198341
# age         0.299008
# smoker      0.787251
# charges     1.000000
# Name: charges, dtype: float64

# %%
f, ax = plt.subplots(figsize=(10, 8))
corr = data.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(240,10,as_cmap=True),square=True, ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### A strong correlation is observed only with the fact of smoking the patient, followed by age. To be honest, I expected a higher correlation with bmi. Well. We investigate smoking in more detail.

# %% [markdown]
# First, let's look at the distribution of charges. This will help us to know how much patients spend on treatment on average.

# %%
f= plt.figure(figsize=(12,5))

ax=f.add_subplot(121)
sns.distplot(data[(data.smoker == 1)]["charges"],color='c',ax=ax)
ax.set_title('Distribution of charges for smokers')

ax=f.add_subplot(122)
sns.distplot(data[(data.smoker == 0)]['charges'],color='b',ax=ax)
ax.set_title('Distribution of charges for non-smokers')
# Out:
# Text(0.5, 1.0, 'Distribution of charges for non-smokers')

# %% [markdown]
# Smoking patients spend more on treatment. But there is a feeling that the number of non-smoking patients is greater. Going to check it.

# %%
sns.catplot(x="smoker", kind="count",hue = 'sex', palette="pink", data=data)

# %% [markdown]
# Please note that women are coded with the symbol " 1 "and men - "0". Thus non-smoking people and the truth more. Also we can notice that more male smokers than women smokers. It can be assumed that the total cost of treatment in men will be more than in women, given the impact of smoking. Maybe we'll check it out later. And some more useful visualizations

# %%
plt.figure(figsize=(12,5))
plt.title("Box plot for charges of women")
sns.boxplot(y="smoker", x="charges", data =  data[(data.sex == 1)] , orient="h", palette = 'magma')
# Out:
# <AxesSubplot:title={'center':'Box plot for charges of women'}, xlabel='charges', ylabel='smoker'>

# %%
plt.figure(figsize=(12,5))
plt.title("Box plot for charges of men")
sns.boxplot(y="smoker", x="charges", data =  data[(data.sex == 0)] , orient="h", palette = 'rainbow')
# Out:
# <AxesSubplot:title={'center':'Box plot for charges of men'}, xlabel='charges', ylabel='smoker'>

# %% [markdown]
# Now let's pay attention to the age of the patients. First, let's look at how age affects the cost of treatment, and also look at patients of what age more in our data set.

# %%
plt.figure(figsize=(12,5))
plt.title("Distribution of age")
ax = sns.distplot(data["age"], color = 'g')

# %% [markdown]
# We have patients under 20 in our data set. 18 years old is the minimum age of patients in our set. The maximum age is 64 years. My personal interest is whether there are smokers among patients 18 years.

# %%
sns.catplot(x="smoker", kind="count",hue = 'sex', palette="rainbow", data=data[(data.age == 18)])
plt.title("The number of smokers and non-smokers (18 years old)")
# Out:
# Text(0.5, 1.0, 'The number of smokers and non-smokers (18 years old)')

# %% [markdown]
# Oh. I was hoping the result would be different. 18 years old - a very young age. Does smoking affect the cost of treatment at this age?

# %%
plt.figure(figsize=(12,5))
plt.title("Box plot for charges 18 years old smokers")
sns.boxplot(y="smoker", x="charges", data = data[(data.age == 18)] , orient="h", palette = 'pink')
# Out:
# <AxesSubplot:title={'center':'Box plot for charges 18 years old smokers'}, xlabel='charges', ylabel='smoker'>

# %% [markdown]
# Oh. As we can see, even at the age of 18 smokers spend much more on treatment than non-smokers. Among non-smokers we are seeing some " tails." I can assume that this is due to serious diseases or accidents. Now let's see how the cost of treatment depends on the age of smokers and non-smokers patients

# %%
g = sns.jointplot(x="age", y="charges", data = data[(data.smoker == 0)], color="m")
g.set_axis_labels("age", "charges")
ax.set_title('Distribution of charges and age for non-smokers')
# Out:
# Text(0.5, 1.0, 'Distribution of charges and age for non-smokers')

# %%
g = sns.jointplot(x="age", y="charges", data = data[(data.smoker == 1)], color="c")
g.set_axis_labels("age", "charges")
ax.set_title('Distribution of charges and age for smokers')
# Out:
# Text(0.5, 1.0, 'Distribution of charges and age for smokers')

# %% [markdown]
# In non-smokers, the cost of treatment increases with age. That makes sense. So take care of your health, friends! In smoking people, we do not see such dependence. Such a strong effect of Smoking on the cost of treatment would be more logical to judge having a set of data with a large number of records and signs. But we work with what we have! Let's pay attention to bmi. I am surprised that this figure but affects the cost of treatment in patients. Or are we on a diet for nothing?

# %%
plt.figure(figsize=(12,5))
plt.title("Distribution of bmi")
ax = sns.distplot(data["bmi"], color = 'm')

# %% [markdown]
# There's something insanely beautiful about this distribution, isn't there?
# The average BMI in patients is 30.

# %% [markdown]
# With a value equal to 30 starts obesity. Let's start to explore! First, let's look at the distribution of costs in patients with BMI greater than 30 and less than 30.

# %%
plt.figure(figsize=(12,5))
plt.title("Distribution of charges for patients with BMI greater than 30")
ax = sns.distplot(data[(data.bmi >= 30)]['charges'], color = 'm')

# %%
plt.figure(figsize=(12,5))
plt.title("Distribution of charges for patients with BMI less than 30")
ax = sns.distplot(data[(data.bmi < 30)]['charges'], color = 'b')

# %% [markdown]
# Patients with BMI above 30 spend more on treatment!

# %%
g = sns.jointplot(x="bmi", y="charges", data = data, color="r")
#g.plot_joint(plt.scatter, c="w", s=30, linewidth=1, marker="+")
#g.ax_joint.collections[0].set_alpha(0)
g.set_axis_labels("bmi", "charges")
ax.set_title('Distribution of bmi and charges')
# Out:
# Text(0.5, 1.0, 'Distribution of bmi and charges')

# %%
plt.figure(figsize=(10,6))
ax = sns.scatterplot(x='bmi',y='charges',data=data,palette='magma',hue='smoker')
ax.set_title('Scatter plot of charges and bmi')

sns.lmplot(x="bmi", y="charges", hue="smoker", data=data, palette = 'magma', size = 8)

# %% [markdown]
# Let's pay attention to children. First, let's see how many children our patients have.

# %%
sns.catplot(x="children", kind="count", palette="rocket", data=data, size = 6)

# %% [markdown]
# Most patients do not have children. Perfectly that some have 5 children! Children are happiness:) I wonder if people who have children smoke

# %%
sns.catplot(x="smoker", kind="count", palette="rainbow",hue = "sex",
            data=data[(data.children > 0)], size = 6)
ax.set_title('Smokers and non-smokers who have childrens')
# Out:
# Text(0.5, 1.0, 'Smokers and non-smokers who have childrens')

# %% [markdown]
# But I am glad that non-smoking parents are much more!

# %% [markdown]
# Let's start with the usual linear regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error         # Evaluating Model

# %%
x = data.drop(['charges'], axis = 1)
y = data.charges

x_train,x_test,y_train,y_test = train_test_split(x,y, random_state = 0)
lr = LinearRegression().fit(x_train,y_train)

y_train_pred = lr.predict(x_train)
y_test_pred = lr.predict(x_test)

print(lr.score(x_test,y_test))
# Out:
# 0.7962732059725786

# %% [markdown]
# Not bad for such a lazy implementation, even without data normalization:D After all, the data will not always be so "good". Now let's add polynomial signs. And look at the result.

# %%
#data.hist()

# %%
X = data.drop(['charges','region'], axis = 1)
Y = data.charges



quad = PolynomialFeatures (degree =2)
x_quad = quad.fit_transform(X)

X_train,X_test,Y_train,Y_test = train_test_split(x_quad,Y, random_state = 0)

plr = LinearRegression().fit(X_train,Y_train)

Y_train_pred = plr.predict(X_train)
Y_test_pred = plr.predict(X_test)

print(plr.score(X_test,Y_test))
# Out:
# 0.8849197344147235

# %% [markdown]
# # Creating my own data set and predicting

# %%
dataNew = [[35,0,38,2,1], [23,1,45,1,0]]
# Create the pandas DataFrame
df = pd.DataFrame(dataNew, columns = ['age', 'sex','bmi','children','smoker'])
 
# print dataframe.
df
# Out:
#    age  sex  bmi  children  smoker
# 0   35    0   38         2       1
# 1   23    1   45         1       0

# %%
df_quad = quad.fit_transform(df)

# %%
plr.predict(df_quad)
# Out:
# array([42096.9274047 ,  2716.95380313])
